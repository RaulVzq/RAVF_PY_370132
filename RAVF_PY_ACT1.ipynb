# %%
print("HOLA MUNDO :)");
# Out:
# HOLA MUNDO :)

# %%
num1=0
num2=0
suma=0
print("Ingrese un numero entero: ")
num1=int(input())
print("Ingrese un segundo numero entero: ")
num2=int(input())
suma=num1+num2
print("El resultado de la suma es: ",suma)
# Out:
# Ingrese un numero entero:
# 10
# Ingrese un segundo numero entero:
# 20
# El resultado de la suma es:  30

# %%
num1=0
num2=0
suma=0
resta=0
multi=0
divi=0
print("Ingrese un numero entero: ")
num1=int(input())
print("Ingrese un segundo numero entero: ")
num2=int(input())
suma=num1+num2
resta=num1-num2
multi=num1*num2
divi=num1/num2
print("El resultado de la suma de ambos numeros es:",suma)
print("El resultado de la resta de amnbos numeros es:",resta)
print("El resultado de la multiplicacion de ambos numeros es:",multi)
print("El resultado de la division de ambos numeros es:",divi)
# Out:
# Ingrese un numero entero:
# 2
# Ingrese un segundo numero entero:
# 10
# El resultado de la suma de ambos numeros es: 12
# El resultado de la resta de amnbos numeros es: -8
# El resultado de la multiplicacion de ambos numeros es: 20
# El resultado de la division de ambos numeros es: 0.2

# %%
base=0
altura=0
area=0
print("Ingrese el tamaño de la base del triangulo")
base=float(input())
print("Ingrese la altura del triangulo")
altura=float(input())
area=(base*altura)/2
print("El area de su triangulo es de",area)
# Out:
# Ingrese el tamaño de la base del triangulo
# 40
# Ingrese la altura del triangulo
# 10
# El area de su triangulo es de 200.0

# %%
cm=0
pies=0
pulg=0
print("Ingrese la medida (en cm) a convertir: ")
cm=float(input())
pies=cm/30.48
pulg=cm/2.54
print("Su medida en pies es equivalente a",pies)
print("Su medida en pulgadas es equivalente a",pulg)
# Out:
# Ingrese la medida (en cm) a convertir:
# 30
# Su medida en pies es equivalente a 0.984251968503937
# Su medida en pulgadas es equivalente a 11.811023622047244

# %%
cel=0
faren=0
kelvin=0

print("Ingrese la temperatura de su preferencia en grados Celcius (C)")
cel=float(input())
faren=((cel*9)/5)+32
kelvin=cel+273.15
print("Temperatura de grado celcius (c) a grados fharenheit (f)",faren)
print("Temperatura de grados celcius (c) a grados kelvin (k)",kelvin)
# Out:
# Ingrese la temperatura de su preferencia en grados Celcius (C)
# 27
# Temperatura de grado celcius (c) a grados fharenheit (f) 80.6
# Temperatura de grados celcius (c) a grados kelvin (k) 300.15

# %%
calif1=0
calif2=0
calif3=0
calif4=0
prom=0

print("Calificaciones de Fulanito Gonzales")
print("Ingrese la calificacion en Español")
calif1=float(input())
print("Ingrese la calificacion en Matematicas")
calif2=float(input())
print("Ingrese la calificacion en Ciencias")
calif3=float(input())
print("Ingrese la calificacion en Historia")
calif4=float(input())
prom=(calif4+calif3+calif2+calif1)/4

print("Calificacion en Español",calif1)
print("calificacion en Matematicas",calif2)
print("calificacion en Ciencias",calif3)
print("calificacion en Historia",calif4)
print("promedio final",prom)
# Out:
# Calificaciones de Fulanito Gonzales
# Ingrese la calificacion en Español
# 9
# Ingrese la calificacion en Matematicas
# 9
# Ingrese la calificacion en Ciencias
# 9
# Ingrese la calificacion en Historia
# 10
# Calificacion en español 9.0
# calificacion en matematicas 9.0
# calificacion en ciencias 9.0
# calificacion en historia 10.0
# promedio final 9.25
